# %%
import os

# List of file names (make sure these match the names of your uploaded files)
file_names = ['01 Harry Potter and the Sorcerers Stone.txt', '02 Harry Potter and the Chamber of Secrets.txt', '03 Harry Potter and the Prisoner of Azkaban.txt', '04 Harry Potter and the Goblet of Fire.txt', '05 Harry Potter and the Order of the Phoenix.txt', '06 Harry Potter and the Half-Blood Prince.txt', '07 Harry Potter and the Deathly Hallows.txt']

# Output file where the merged content will be saved
output_file = '/content/merged_file.txt'

# Open the output file in write mode
with open(output_file, 'w') as outfile:
    # Loop through each file and append its content to the output file
    for file_name in file_names:
        with open(file_name, 'r') as infile:
            outfile.write(infile.read())
            outfile.write("\n")  # Optional: add a newline after each file's content

print(f'Merged file saved as {output_file}')
# Out:
# Merged file saved as /content/merged_file.txt

# %%
from google.colab import files

files.download(output_file)
